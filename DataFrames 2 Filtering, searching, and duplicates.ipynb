# %%
import pandas as pd

# %% [markdown]
# # First thing first - memory optimization on import

# %%
df = pd.read_csv("employees.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df["Team"].nunique()
# Out:
# 10

# %%
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df["Senior Management"] = df["Senior Management"].astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), float64(1), int64(1), object(3)
# memory usage: 42.6+ KB

# %% [markdown]
# ## Lets go ahead and convert dates and times to datetimes too

# %%
# Note that times w/o dates are assumed to be datetime.today()
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# # Filtering a dataframe based on a single condition

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-07-13 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ### Fetch all Male employees

# %%
df["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
# You can do operations inside of the brackets apparently, cool
df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-07-13 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-07-13 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-07-13 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-07-13 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-07-13 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
# This is called a mask, and you should make it separate variable for clarity's sake
# Holy shit, python lets you do evaluations inside of assingments? Or is this just a polymorphed method?
mask = df["Team"] == "Finance"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-07-13 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-07-13 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-07-13 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-07-13 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-07-13 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-07-13 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-07-13 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
mask_sm = df["Senior Management"]
df[mask_sm]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-07-13 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-07-13 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-07-13 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-07-13 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-07-13 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-07-13 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-07-13 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
mask_nm = df["Team"] != "Marketing"
df[mask_nm]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-07-13 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-07-13 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-07-13 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-07-13 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [902 rows x 8 columns]

# %%
df[df["Salary"] > 110000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-07-13 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2022-07-13 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2022-07-13 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2022-07-13 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-07-13 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-07-13 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
# Dude wtf, dates are so much easier... although we need to consider timezones. I'm sure he will get into it...
date_mask = df["Start Date"] <= "1985-01-01"
df[date_mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2022-07-13 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2022-07-13 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2022-07-13 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2022-07-13 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2022-07-13 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2022-07-13 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2022-07-13 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2022-07-13 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2022-07-13 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# # Filter with multiple conditions

# %%
office = pd.read_csv("the_office.csv", parse_dates=["Airdate"])
office = office.drop_duplicates(subset=["Season", "Name", "Director", "Writer", "Airdate", "Viewership"])
office
# Out:
#      Season  Episode              Name         Director  \
# 0         1        1             Pilot       Ken Kwapis
# 1         1        2     Diversity Day       Ken Kwapis
# 2         1        3       Health Care  Ken Whittingham
# 3         1        4      The Alliance     Bryan Gordon
# 4         1        5        Basketball     Greg Daniels
# ..      ...      ...               ...              ...
# 194       9       19     Stairmageddon        Matt Sohn
# 195       9       20    Paper Airplane     Jesse Peretz
# 196       9       21  Livin' the Dream    Jeffrey Blitz
# 197       9       22          A.A.R.M.     David Rogers
# 199       9       24            Finale       Ken Kwapis
#
#                                                 Writer    Airdate  Viewership
# 0    Ricky Gervais & Stephen Merchant and Greg Daniels 2005-03-24       11.20
# 1                                          B. J. Novak 2005-03-29        6.00
# 2                                     Paul Lieberstein 2005-04-05        5.80
# 3                                        Michael Schur 2005-04-12        5.40
# 4                                         Greg Daniels 2005-04-19        5.00
# ..                                                 ...        ...         ...
# 194                                       Dan Sterling 2013-04-11        3.83
# 195              Halsted Sullivan & Warren Lieberstein 2013-04-25        3.25
# 196                               Niki Schwartz-Wright 2013-05-02        3.51
# 197                                    Brent Forrester 2013-05-09        4.56
# 199                                       Greg Daniels 2013-05-16        5.69
#
# [188 rows x 7 columns]

# %% [markdown]
# ### Using the AND (&) Operator

# %%
mask1 = office["Writer"] == "Greg Daniels"
mask2 = office["Season"] >= 6
written_by_greg = office[mask1 & mask2]
written_by_greg
# Out:
#      Season  Episode               Name      Director        Writer  \
# 147       7       22  Goodbye, Michael†     Paul Feig  Greg Daniels
# 176       9        1           New Guys  Greg Daniels  Greg Daniels
# 199       9       24             Finale    Ken Kwapis  Greg Daniels
#
#        Airdate  Viewership
# 147 2011-04-28        8.42
# 176 2012-09-20        4.28
# 199 2013-05-16        5.69

# %% [markdown]
# ### Using the OR ( | ) Operator

# %%
mask1 = office["Season"] == 8
mask2 = office["Episode"] == 1
good_episodes = office[mask1 | mask2]
good_episodes.head(3)
# Out:
#     Season  Episode            Name      Director  \
# 0        1        1           Pilot    Ken Kwapis
# 6        2        1     The Dundies  Greg Daniels
# 28       3        1  Gay Witch Hunt    Ken Kwapis
#
#                                                Writer    Airdate  Viewership
# 0   Ricky Gervais & Stephen Merchant and Greg Daniels 2005-03-24       11.20
# 6                                        Mindy Kaling 2005-09-20        9.00
# 28                                       Greg Daniels 2006-09-21        9.11

# %% [markdown]
# ### Using multiple conditions at once

# %%
mask1 = office["Airdate"] < "2012-01-01"
mask2 = office["Writer"] == "Greg Daniels"
mask3 = office["Director"] == "Jeffrey Blitz"
early_episodes = office[mask1 & (mask2 | mask3)]
early_episodes.head(3)
# Out:
#     Season  Episode          Name      Director        Writer    Airdate  \
# 4        1        5    Basketball  Greg Daniels  Greg Daniels 2005-04-19
# 10       2        5     Halloween     Paul Feig  Greg Daniels 2005-10-18
# 16       2       11  Booze Cruise    Ken Kwapis  Greg Daniels 2006-01-05
#
#     Viewership
# 4          5.0
# 10         8.0
# 16         8.7

# %% [markdown]
# ## Checking for stuff with the .isin() method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].fillna("None")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-07-13 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True       None
# 2              False    Finance

# %%
legal = df["Team"] == "Legal"
sales = df["Team"] == "Sales"
product = df["Team"] == "Product"
df[legal | sales | product]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-07-13 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-07-13 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-07-13 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-07-13 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-07-13 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-07-13 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-07-13 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-07-13 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
mask = df["Team"].isin(["Legal", "Sales", "Product"])
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-07-13 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-07-13 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-07-13 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-07-13 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-07-13 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-07-13 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-07-13 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-07-13 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## Checking with str.contains

# %%
Team = "Sale"
mask = df["Team"].str.contains(Team)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 13        Gary    Male 2008-01-27 2022-07-13 23:40:00  109831    5.831
# 35     Theresa  Female 2006-10-10 2022-07-13 01:12:00   85182   16.675
# 45       Roger    Male 1980-04-17 2022-07-13 11:32:00   88010   13.886
# 49       Chris     NaN 1980-01-24 2022-07-13 12:13:00  113590    3.055
# 51         NaN     NaN 2011-12-17 2022-07-13 08:29:00   41126   14.009
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2022-07-13 11:15:00   89443   17.940
# 964      Bruce    Male 1980-05-07 2022-07-13 20:00:00   35802   12.391
# 972     Victor     NaN 2006-07-28 2022-07-13 14:49:00   76381   11.159
# 975      Susan  Female 1995-04-07 2022-07-13 22:05:00   92436   12.467
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management   Team
# 13               False  Sales
# 35               False  Sales
# 45                True  Sales
# 49               False  Sales
# 51                True  Sales
# ..                 ...    ...
# 963               True  Sales
# 964               True  Sales
# 972               True  Sales
# 975              False  Sales
# 999               True  Sales
#
# [94 rows x 8 columns]

# %% [markdown]
# ## Using the .isnull() and .notnull() Methods

# %%
mask = df["Gender"].isnull()
df[mask]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22 2022-07-13 19:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08 2022-07-13 01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11 2022-07-13 18:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20 2022-07-13 14:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28 2022-07-13 01:08:00   66582   11.308
# ..         ...    ...        ...                 ...     ...      ...
# 961    Antonio    NaN 1989-06-18 2022-07-13 21:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28 2022-07-13 14:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10 2022-07-13 20:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10 2022-07-13 16:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23 2022-07-13 06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
mask = df["Gender"].notnull()
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-07-13 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-07-13 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-07-13 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-07-13 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-07-13 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-07-13 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-07-13 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                  None
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ## Using the .between() Method

# %%
mask = df["Salary"].between(60000, 70000)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-07-13 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2022-07-13 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2022-07-13 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2022-07-13 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2022-07-13 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2022-07-13 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2022-07-13 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2022-07-13 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2022-07-13 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                  None
# 6                 True               Product
# 10                True                  None
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
df[df["Bonus %"].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2022-07-13 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2022-07-13 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2022-07-13 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2022-07-13 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2022-07-13 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2022-07-13 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2022-07-13 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2022-07-13 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2022-07-13 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True          None
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %% [markdown]
# ## .between() works on datetimes

# %%
datetime_mask = df["Start Date"].between("1991-01-01", "1992-01-01")
df[datetime_mask].head(5)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2022-07-13 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2022-07-13 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2022-07-13 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2022-07-13 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2022-07-13 02:24:00  124488   14.837
#
#      Senior Management             Team
# 27               False            Legal
# 75                True  Human Resources
# 88                True            Legal
# 116               True            Legal
# 148               True            Sales

# %%
# Pandas is good at parsing times apparently lol
df[df["Last Login Time"].between("2022-07-12 08:30", "2022-07-13 12:00")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-07-13 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-07-13 11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# 7          NaN  Female 2015-07-20 2022-07-13 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2022-07-13 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 988      Alice  Female 2004-10-05 2022-07-13 09:34:00   47638   11.209
# 991       Rose  Female 2002-08-25 2022-07-13 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-07-13 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-07-13 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-07-13 06:30:00   42392   19.675
#
#      Senior Management             Team
# 1                 True             None
# 2                False          Finance
# 5                False            Legal
# 7                 True          Finance
# 8                 True      Engineering
# ..                 ...              ...
# 988              False  Human Resources
# 991               True        Marketing
# 992               True          Finance
# 995              False     Distribution
# 996              False          Finance
#
# [496 rows x 8 columns]

# %% [markdown]
# # Check for duplicate rows with .duplicated() method

# %%
df = df.sort_values("First Name")
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-07-13 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-07-13 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-07-13 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-07-13 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-07-13 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df["First Name"].duplicated(keep="first")
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df["First Name"].duplicated(keep="last")
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
# Throw out anything thats duplicated. Even the first and last. Only totally unique values allowed here.
mask = ~df["First Name"].duplicated(keep=False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-07-13 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-07-13 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-07-13 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-07-13 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-07-13 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-07-13 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-07-13 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-07-13 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-07-13 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ## Drop Duplicates w/ .drop_duplicates() method

# %% [markdown]
# #### Default behavior drops only wholey duplicate rows

# %%
len(df)
# Out:
# 1000

# %%
df = df.drop_duplicates(subset=["First Name"], keep="first")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-07-13 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-07-13 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-07-13 03:54:00  111786    3.592
# 959     Albert    Male 1992-09-19 2022-07-13 02:35:00   45094    5.850
# 988      Alice  Female 2004-10-05 2022-07-13 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 512      Wanda  Female 1993-04-06 2022-07-13 03:11:00   78883   19.695
# 943      Wayne    Male 2006-09-08 2022-07-13 11:09:00   67471    2.728
# 941    William    Male 1997-06-26 2022-07-13 08:33:00  104840   15.653
# 175     Willie    Male 1998-02-17 2022-07-13 20:20:00  146651    1.451
# 7          NaN  Female 2015-07-20 2022-07-13 10:43:00   45906   11.598
#
#      Senior Management                  Team
# 101               True             Marketing
# 137              False          Distribution
# 300               True           Engineering
# 959               True  Business Development
# 988              False       Human Resources
# ..                 ...                   ...
# 512              False                  None
# 943              False           Engineering
# 941               True           Engineering
# 175               True           Engineering
# 7                 True               Finance
#
# [201 rows x 8 columns]
